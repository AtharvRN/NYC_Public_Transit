# %% [markdown]
# # Subway Wait Time Analysis
#
# Outline data sources, modeling assumptions, and quick diagnostics for Subway stations.

# %% [markdown]
# ## Checklist
# - [ ] Load raw datasets relevant to Subway stations
# - [ ] Aggregate arrivals per node/hour
# - [ ] Compute mean/variance + dispersion
# - [ ] Fit NB vs Poisson
# - [ ] Visualize waits and select a heuristic

# %%
# TODO: implement loader + analysis for Subway stations
